# %%
pip install Faker
# Out:
# Requirement already satisfied: Faker in c:\users\jairo\appdata\local\programs\python\python312\lib\site-packages (24.11.0)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\jairo\appdata\local\programs\python\python312\lib\site-packages (from Faker) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\jairo\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.4->Faker) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from faker import Faker
fake = Faker()

# %%
lista = []

# %%
for _ in range(10000):
    lista.append({'nombre':fake.name(), 'apellido':fake.last_name(), 'email':fake.email(), 'direccion':fake.address()})
  #print(fake.name(),fake.last_name(), fake.email(), fake.address())

# 'Adaline Reichel'
# 'Dr. Santa Prosacco DVM'
# 'Noemy Vandervort V'
# 'Lexi O'Conner'
# 'Gracie Weber'
# 'Roscoe Johns'
# 'Emmett Lebsack'
# 'Keegan Thiel'
# 'Wellington Koelpin II'
# 'Ms. Karley Kiehn V'

# %%
lista
# Out:
# [{'nombre': 'George Hernandez PhD',
#   'apellido': 'Garcia',
#   'email': 'rnichols@example.com',
#   'direccion': '901 Reyes Ville\nWardchester, MH 18727'},
#  {'nombre': 'Anna Beck',
#   'apellido': 'Clark',
#   'email': 'gomezsteven@example.com',
#   'direccion': '8312 Cindy Mountains Apt. 646\nNorth Summerland, IA 12091'},
#  {'nombre': 'Michael Williams',
#   'apellido': 'Baker',
#   'email': 'reynoldsbrittney@example.org',
#   'direccion': '288 Mcdonald Crossing\nSouth Georgemouth, DE 52524'},
#  {'nombre': 'Mr. Stephen Simpson',
#   'apellido': 'Perez',
#   'email': 'paullopez@example.net',
#   'direccion': '631 Timothy Loop\nAntonioborough, MI 88544'},
#  {'nombre': 'Ryan Allen',
#   'apellido': 'Mason',
#   'email': 'cfranklin@example.org',
#   'direccion': '31938 Amber Lock Apt. 984\nLake Sierra, VA 51249'},
#  {'nombre': 'Lisa Young',
#   'apellido': 'Velazquez',
#   'email': 'monicahernandez@example.net',
#   'direccion': '63798 Maxwell Circle Suite 388\nGriffinfurt, PW 84897'},
#  {'nombre': 'Sean Benitez',
#   'apellido': 'Duffy',
#   'email': 'yjohnson@example.org',
#   'direccion': '4401 Walsh Shore\nMillsland, OH 46356'},
#  {'nombre': 'Joseph Moore',
#   'apellido': 'Davis',
#   'email': 'tammy93@example.net',
#   'direccion': '5506 Tara Way Suite 755\nBlevinshaven, WA 96021'},
#  {'nombre': 'Joseph Mccullough',
#   'apellido': 'Scott',
#   'email': 'leepatrick@example.org',
#   'direccion': 'PSC 9526, Box 7517\nAPO AP 34360'},
#  {'nombre': 'Stacy Rogers',
#   'apellido': 'Carpenter',
#   'email': 'katherine08@example.com',
#   'direccion': '131 Green Ranch Apt. 706\nVanessaside, NY 58338'},
#  {'nombre': 'Sabrina Cole',
#   'apellido': 'Brown',
#   'email': 'englishbrandi@example.org',
#   'direccion': '47621 Harvey Heights Suite 134\nNorth Deborah, TN 62216'},
#  {'nombre': 'Brandon Nguyen',
#   'apellido': 'Andrews',
#   'email': 'sgarcia@example.org',
#   'direccion': '6953 Miller Tunnel\nNorth Katherinemouth, ND 75812'},
#  {'nombre': 'Maxwell Jackson',
#   'apellido': 'Waters',
#   'email': 'watsonlindsey@example.com',
#   'direccion': '7509 Hicks Mountain Suite 527\nNew Aaron, GU 91746'},
#  {'nombre': 'Samuel Jones',
#   'apellido': 'Davis',
#   'email': 'robertjackson@example.net',
#   'direccion': 'PSC 1619, Box 3298\nAPO AA 71230'},
#  {'nombre': 'Kelly Gomez',
#   'apellido': 'Andrews',
#   'email': 'eclark@example.org',
#   'direccion': '4025 Cooper Run\nNewmanside, MD 43199'},
#  {'nombre': 'Frances Singleton',
#   'apellido': 'Bell',
#   'email': 'mary20@example.org',
#   'direccion': '26946 Susan Overpass\nMayermouth, CO 65384'},
#  {'nombre': 'David Hawkins',
#   'apellido': 'Figueroa',
#   'email': 'ejohnson@example.org',
#   'direccion': '80246 Baker Expressway Apt. 093\nRodriguezchester, IA 89448'},
#  {'nombre': 'Jill Ryan',
#   'apellido': 'Gilbert',
#   'email': 'andrew48@example.net',
#   'direccion': '2311 Teresa Greens\nHeidibury, OH 94258'},
#  {'nombre': 'Angela Wagner',
#   'apellido': 'Holland',
#   'email': 'mmay@example.org',
#   'direccion': '7152 Jeffrey Bridge\nEast Cheryl, VA 57976'},
#  {'nombre': 'Ariana Carpenter',
#   'apellido': 'James',
#   'email': 'marywebster@example.com',
#   'direccion': '892 Johnny Stream Apt. 241\nChanchester, ME 72630'},
#  {'nombre': 'Cory Thomas',
#   'apellido': 'Robinson',
#   'email': 'dcampbell@example.net',
#   'direccion': '3045 Steve Terrace Suite 537\nHeathermouth, CT 69370'},
#  {'nombre': 'Katie Nichols',
#   'apellido': 'Carter',
#   'email': 'stephen31@example.com',
#   'direccion': '03229 Parsons Forge Suite 034\nJamesborough, IL 34849'},
#  {'nombre': 'Darren Holmes',
#   'apellido': 'Simpson',
#   'email': 'robertsdonna@example.net',
#   'direccion': '074 Barnes Mountains Suite 480\nEast Austin, GA 70074'},
#  {'nombre': 'Gary Alvarado',
#   'apellido': 'Meyer',
#   'email': 'shelley78@example.com',
#   'direccion': '555 Foster Motorway Suite 170\nNorth John, MD 39995'},
#  {'nombre': 'Joseph Blackburn',
#   'apellido': 'Freeman',
#   'email': 'valerie39@example.net',
#   'direccion': '7902 Lawson Port Apt. 980\nNorth Ashley, WA 82314'},
#  {'nombre': 'Stacy Gray',
#   'apellido': 'Lopez',
#   'email': 'brettwilson@example.com',
#   'direccion': '43553 Miles Key Suite 328\nHowellton, MD 24531'},
#  {'nombre': 'Kevin Martinez',
#   'apellido': 'Flores',
#   'email': 'phillipsvanessa@example.com',
#   'direccion': '202 Melissa Mission\nWest Marcus, ME 76955'},
#  {'nombre': 'Bradley Roberts',
#   'apellido': 'Hayes',
#   'email': 'dakota68@example.net',
#   'direccion': '42080 Kyle Lakes\nBakerberg, NY 70921'},
#  {'nombre': 'Christine Davis',
#   'apellido': 'Taylor',
#   'email': 'anitascott@example.org',
#   'direccion': '2939 Lisa Common Apt. 494\nClarkland, DC 52949'},
#  {'nombre': 'Gail Preston',
#   'apellido': 'Camacho',
#   'email': 'diazlaura@example.org',
#   'direccion': 'Unit 1842 Box 1652\nDPO AA 01609'},
#  {'nombre': 'Matthew Ruiz',
#   'apellido': 'Long',
#   'email': 'ucobb@example.net',
#   'direccion': '42333 April Stream\nLloydberg, MD 94699'},
#  {'nombre': 'Cameron Smith',
#   'apellido': 'Edwards',
#   'email': 'john51@example.net',
#   'direccion': '66363 Oneill Ranch Suite 869\nWest Joshuaville, MH 18193'},
#  {'nombre': 'Sherry Erickson',
#   'apellido': 'Garcia',
#   'email': 'grantjensen@example.net',
#   'direccion': 'PSC 8794, Box 2436\nAPO AA 65356'},
#  {'nombre': 'Ray Moore',
#   'apellido': 'Cross',
#   'email': 'robertselizabeth@example.net',
#   'direccion': '88893 Jennifer Expressway\nRodneyland, VA 19646'},
#  {'nombre': 'Mrs. Deanna Huffman',
#   'apellido': 'Yoder',
#   'email': 'opineda@example.com',
#   'direccion': '521 Smith Radial\nEast Vanessa, FM 67476'},
#  {'nombre': 'Donald Davis',
#   'apellido': 'Ward',
#   'email': 'davisaaron@example.net',
#   'direccion': '985 Miller Coves\nNew Laurenshire, AZ 64599'},
#  {'nombre': 'Maria Richards DDS',
#   'apellido': 'Carlson',
#   'email': 'rdavis@example.net',
#   'direccion': '09919 Kayla Forge Apt. 758\nLake Reginaview, HI 31160'},
#  {'nombre': 'Gabriela Salas',
#   'apellido': 'Skinner',
#   'email': 'pricebrooke@example.net',
#   'direccion': '0360 Heather Ramp Suite 378\nDavisfort, MA 75750'},
#  {'nombre': 'Brittany Bailey',
#   'apellido': 'Hudson',
#   'email': 'megan38@example.org',
#   'direccion': '78918 Lisa Vista\nNew Andrew, NY 07356'},
#  {'nombre': 'William Bennett',
#   'apellido': 'Robertson',
#   'email': 'mcintoshsusan@example.net',
#   'direccion': '9473 James Walks Suite 405\nRosetown, OH 91608'},
#  {'nombre': 'Michele Wood',
#   'apellido': 'Townsend',
#   'email': 'evansmichael@example.com',
#   'direccion': 'PSC 0789, Box 1546\nAPO AA 21992'},
#  {'nombre': 'Alan Diaz',
#   'apellido': 'Hill',
#   'email': 'richardthompson@example.org',
#   'direccion': '52496 Willie Rue\nSouth Mirandatown, KS 84192'},
#  {'nombre': 'Michael Barnes',
#   'apellido': 'Ward',
#   'email': 'simmonsalicia@example.com',
#   'direccion': '965 Nichols Greens\nSouth Nancystad, MI 69781'},
#  {'nombre': 'Julie Rodriguez',
#   'apellido': 'Stanley',
#   'email': 'perezashley@example.com',
#   'direccion': '324 Aaron Ports Suite 613\nNew Cristina, TX 91604'},
#  {'nombre': 'Tammy Taylor',
#   'apellido': 'Hogan',
#   'email': 'jacob67@example.org',
#   'direccion': '40540 Melinda Mountains\nJenniferfurt, AZ 72633'},
#  {'nombre': 'Shannon Charles',
#   'apellido': 'Garcia',
#   'email': 'scottrichard@example.org',
#   'direccion': '183 Campbell Fork\nEast Rebecca, OR 94003'},
#  {'nombre': 'Anita Gross',
#   'apellido': 'Olson',
#   'email': 'vmarks@example.net',
#   'direccion': '2883 Robert Walk Suite 901\nSouth Shanebury, ND 12132'},
#  {'nombre': 'Jeffery Carrillo',
#   'apellido': 'Lewis',
#   'email': 'nwallace@example.net',
#   'direccion': '5065 Velasquez Loop\nNew Tinaside, NJ 59392'},
#  {'nombre': 'Daniel Archer',
#   'apellido': 'Anderson',
#   'email': 'karenfisher@example.com',
#   'direccion': '316 Page Lights\nPort Tiffany, DC 39386'},
#  {'nombre': 'Angela Lee',
#   'apellido': 'Wade',
#   'email': 'carterleonard@example.org',
#   'direccion': '759 Meyers Hill\nSouth Jackie, KS 41849'},
#  {'nombre': 'Jessica King',
#   'apellido': 'Sullivan',
#   'email': 'ksuarez@example.com',
#   'direccion': '2841 Rosario Street Suite 353\nSawyermouth, IL 19249'},
#  {'nombre': 'Kevin Henderson',
#   'apellido': 'Rodgers',
#   'email': 'halleric@example.net',
#   'direccion': '786 Douglas Mount\nCabrerastad, UT 27265'},
#  {'nombre': 'Amanda Smith',
#   'apellido': 'Cox',
#   'email': 'fyork@example.org',
#   'direccion': '073 Rojas Divide Apt. 346\nMorganhaven, ID 86482'},
#  {'nombre': 'Dr. Rebecca White',
#   'apellido': 'Garcia',
#   'email': 'gparker@example.net',
#   'direccion': 'USS Shepard\nFPO AE 45954'},
#  {'nombre': 'Barbara Osborne',
#   'apellido': 'Schneider',
#   'email': 'allenanne@example.com',
#   'direccion': '895 Alexis View Apt. 796\nLake Sherrymouth, RI 69093'},
#  {'nombre': 'Shirley Hernandez',
#   'apellido': 'Welch',
#   'email': 'parkdarlene@example.org',
#   'direccion': '232 Shannon Row Suite 202\nDaltonview, NE 50806'},
#  {'nombre': 'Marie Graham',
#   'apellido': 'Weaver',
#   'email': 'qortiz@example.com',
#   'direccion': '83338 Kevin Ridge\nEast Bethville, KY 82072'},
#  {'nombre': 'Allen Vaughn',
#   'apellido': 'Garcia',
#   'email': 'blindsey@example.net',
#   'direccion': '491 Guerrero Ville Suite 308\nZacharyport, PR 17839'},
#  {'nombre': 'Benjamin Dawson',
#   'apellido': 'Chavez',
#   'email': 'holly79@example.net',
#   'direccion': '72589 Powell Flat Apt. 313\nDunlapport, SD 50135'},
#  {'nombre': 'Andrea White',
#   'apellido': 'Clark',
#   'email': 'ajones@example.com',
#   'direccion': '5336 Blankenship Inlet\nAllenstad, GA 79006'},
#  {'nombre': 'Amy Wong',
#   'apellido': 'Rogers',
#   'email': 'eric98@example.com',
#   'direccion': 'Unit 1014 Box 5938\nDPO AA 27709'},
#  {'nombre': 'Omar Smith',
#   'apellido': 'Rush',
#   'email': 'farrellalan@example.com',
#   'direccion': '7934 Fuller Lake Apt. 312\nEast Michele, MO 43396'},
#  {'nombre': 'Nicholas Walker Jr.',
#   'apellido': 'Walton',
#   'email': 'cartermichael@example.com',
#   'direccion': '252 Williams Street\nRobertfurt, NY 78934'},
#  {'nombre': 'Gerald Harris',
#   'apellido': 'Jackson',
#   'email': 'romerorhonda@example.org',
#   'direccion': '718 Christopher Meadow\nJohnsonhaven, CO 67773'},
#  {'nombre': 'Kenneth Ryan',
#   'apellido': 'Diaz',
#   'email': 'rreed@example.org',
#   'direccion': '259 Smith Square Suite 203\nEast Jennifermouth, RI 77328'},
#  {'nombre': 'Jessica Scott',
#   'apellido': 'Mason',
#   'email': 'hilljudy@example.com',
#   'direccion': '174 Kyle Dam Apt. 998\nMyersburgh, SD 57025'},
#  {'nombre': 'Scott Dunn',
#   'apellido': 'Phillips',
#   'email': 'bradley93@example.com',
#   'direccion': '998 Smith Fort Apt. 001\nWest Davidbury, HI 24272'},
#  {'nombre': 'Edgar Mills',
#   'apellido': 'Terrell',
#   'email': 'eugenesmith@example.com',
#   'direccion': '576 Alexander Rue\nNorth William, GU 39733'},
#  {'nombre': 'Matthew Jones',
#   'apellido': 'Harris',
#   'email': 'curtisstacey@example.org',
#   'direccion': '1301 Todd Manor Apt. 304\nDoylemouth, KY 03988'},
#  {'nombre': 'Amanda Allen',
#   'apellido': 'Cowan',
#   'email': 'larrylynn@example.com',
#   'direccion': '40866 Andrew Pine Suite 505\nBrownburgh, MT 94230'},
#  {'nombre': 'Roy Vaughn',
#   'apellido': 'Hubbard',
#   'email': 'sheryl45@example.com',
#   'direccion': '053 Laura Trace Suite 509\nLake Angelaview, VA 96465'},
#  {'nombre': 'Gregory Flores',
#   'apellido': 'Byrd',
#   'email': 'edunn@example.com',
#   'direccion': '7274 Padilla Islands\nCookport, SD 77157'},
#  {'nombre': 'Brandon Gonzales',
#   'apellido': 'Williams',
#   'email': 'rbrown@example.com',
#   'direccion': '69422 Ann Square Suite 084\nSouth Janice, NV 98218'},
#  {'nombre': 'Shane Hicks',
#   'apellido': 'Green',
#   'email': 'brian56@example.net',
#   'direccion': '05877 Brooks Port Suite 995\nPort Davidchester, NY 87003'},
#  {'nombre': 'Brandon Pierce',
#   'apellido': 'Smith',
#   'email': 'robertlee@example.com',
#   'direccion': '205 Timothy Estates Suite 461\nRobertchester, PR 95542'},
#  {'nombre': 'Erica Mckenzie',
#   'apellido': 'Ross',
#   'email': 'victorianguyen@example.com',
#   'direccion': '661 Ruth Junction Apt. 410\nFloydtown, AZ 61818'},
#  {'nombre': 'Cameron Young',
#   'apellido': 'Sweeney',
#   'email': 'crossmichele@example.org',
#   'direccion': '210 Dixon Vista Apt. 400\nPort Carlos, RI 43065'},
#  {'nombre': 'Barbara Wright',
#   'apellido': 'Brown',
#   'email': 'cyoung@example.net',
#   'direccion': '523 James Well Apt. 492\nLake Laura, MO 17165'},
#  {'nombre': 'Kirk Anderson',
#   'apellido': 'Monroe',
#   'email': 'carl43@example.com',
#   'direccion': '1852 Phillips Bridge\nBellside, GA 26502'},
#  {'nombre': 'Elizabeth Olson',
#   'apellido': 'Carter',
#   'email': 'susangarcia@example.org',
#   'direccion': '21009 Andrea Track\nMonicahaven, CA 43978'},
#  {'nombre': 'Ricardo Santana',
#   'apellido': 'Hanson',
#   'email': 'estradaanthony@example.net',
#   'direccion': 'PSC 2195, Box 2036\nAPO AA 98463'},
#  {'nombre': 'Emily Schroeder',
#   'apellido': 'Wolf',
#   'email': 'aburke@example.net',
#   'direccion': '68969 Tammy Plaza Suite 626\nBullockside, NH 11875'},
#  {'nombre': 'Jeremiah Galloway',
#   'apellido': 'Herrera',
#   'email': 'jose21@example.org',
#   'direccion': '0650 Jason Plain Apt. 914\nNew Cynthia, IL 52278'},
#  {'nombre': 'Patricia Perez',
#   'apellido': 'Conrad',
#   'email': 'ballisaac@example.com',
#   'direccion': '166 Amber Shores Apt. 159\nVasquezstad, MA 68888'},
#  {'nombre': 'Keith Hardy',
#   'apellido': 'Jackson',
#   'email': 'williamfuller@example.org',
#   'direccion': '745 Dawn Union Apt. 479\nDrakeborough, NV 52403'},
#  {'nombre': 'Suzanne Johnson',
#   'apellido': 'Baker',
#   'email': 'wolfrebecca@example.net',
#   'direccion': '7116 Raymond Coves Suite 460\nPort Sheila, MA 06448'},
#  {'nombre': 'Misty Keller',
#   'apellido': 'Hernandez',
#   'email': 'pmoreno@example.org',
#   'direccion': '99926 Amber Ways Apt. 778\nLevyview, SD 34841'},
#  {'nombre': 'Johnny Burke',
#   'apellido': 'Fry',
#   'email': 'martintodd@example.com',
#   'direccion': '5815 Kenneth Terrace Suite 908\nPort Latoyahaven, RI 72478'},
#  {'nombre': 'Dr. Jasmine Chase MD',
#   'apellido': 'Gomez',
#   'email': 'morrisjackie@example.net',
#   'direccion': '7876 Montes Trafficway\nNorth Tom, MS 66959'},
#  {'nombre': 'Christopher Chang',
#   'apellido': 'Green',
#   'email': 'montoyalisa@example.org',
#   'direccion': '195 Castillo Burg Apt. 908\nWest Kelsey, HI 08153'},
#  {'nombre': 'Rebecca Hart',
#   'apellido': 'Patterson',
#   'email': 'mary63@example.com',
#   'direccion': '330 Merritt Rest\nGoodbury, CT 33058'},
#  {'nombre': 'Michelle Arroyo',
#   'apellido': 'Santiago',
#   'email': 'susanrogers@example.com',
#   'direccion': '188 Cruz Valley Apt. 381\nWest Jonathanchester, FL 89761'},
#  {'nombre': 'Kevin Baker',
#   'apellido': 'Mcdonald',
#   'email': 'briancunningham@example.net',
#   'direccion': '924 Jacob Avenue\nPort Dylan, PW 87586'},
#  {'nombre': 'Gregory Taylor',
#   'apellido': 'Moore',
#   'email': 'browntiffany@example.net',
#   'direccion': '78116 Veronica Village Suite 076\nWheelerfort, MS 33921'},
#  {'nombre': 'Ethan Sanchez',
#   'apellido': 'Hutchinson',
#   'email': 'arthurdavis@example.net',
#   'direccion': '103 Jones Shoals Apt. 515\nJeremyberg, CA 15902'},
#  {'nombre': 'Krystal Morris',
#   'apellido': 'Martin',
#   'email': 'fholden@example.net',
#   'direccion': '6506 Bonnie Island\nFrancisshire, NY 64644'},
#  {'nombre': 'Amy Nelson',
#   'apellido': 'Lam',
#   'email': 'christianpalmer@example.net',
#   'direccion': '75660 Jeffrey Wells Apt. 583\nFieldsbury, OH 54717'},
#  {'nombre': 'Stephen Griffith',
#   'apellido': 'Flores',
#   'email': 'toddrichard@example.org',
#   'direccion': '2049 Thomas Expressway\nJonathanton, KS 22053'},
#  {'nombre': 'Shannon Gonzalez',
#   'apellido': 'Brown',
#   'email': 'uosborne@example.org',
#   'direccion': '1961 Greg Springs Suite 344\nSouth Ryanburgh, MA 92099'},
#  {'nombre': 'Kristine Hodge',
#   'apellido': 'Mayo',
#   'email': 'barbara91@example.org',
#   'direccion': '9299 Ford Plaza Suite 330\nSouth Stephanie, NE 18789'},
#  {'nombre': 'Joseph Christian',
#   'apellido': 'Wright',
#   'email': 'richard75@example.com',
#   'direccion': 'PSC 8780, Box 1725\nAPO AE 72074'},
#  {'nombre': 'Zachary Jones',
#   'apellido': 'Edwards',
#   'email': 'klee@example.net',
#   'direccion': '89799 Melissa Estates Apt. 784\nPort Jeremy, NE 49622'},
#  {'nombre': 'Robert Fleming',
#   'apellido': 'Holland',
#   'email': 'megan82@example.net',
#   'direccion': '8007 Michael Expressway Suite 872\nWest Danielhaven, CT 24018'},
#  {'nombre': 'Ruth Martinez',
#   'apellido': 'Armstrong',
#   'email': 'abrown@example.net',
#   'direccion': '9425 Julie Ports Apt. 958\nPort Robertview, MP 61217'},
#  {'nombre': 'John Jimenez',
#   'apellido': 'Smith',
#   'email': 'daniellecarr@example.net',
#   'direccion': '033 Andrew Mill\nPort Rodney, WY 93995'},
#  {'nombre': 'Victoria Adams',
#   'apellido': 'Richardson',
#   'email': 'thomaslydia@example.com',
#   'direccion': '138 Paul Parkway\nReyesport, MD 26126'},
#  {'nombre': 'Jeanette Miller',
#   'apellido': 'Sanchez',
#   'email': 'daniel54@example.org',
#   'direccion': '862 Amanda Ridge\nLake Michael, PW 46617'},
#  {'nombre': 'Shawn Ryan',
#   'apellido': 'Castillo',
#   'email': 'ruth80@example.org',
#   'direccion': '2496 Lucas Loop Suite 076\nNew Scottburgh, AZ 76458'},
#  {'nombre': 'Ronald Lutz',
#   'apellido': 'Carpenter',
#   'email': 'mathewsmichelle@example.net',
#   'direccion': '664 Kelly Orchard Suite 058\nNew Benjamintown, HI 40544'},
#  {'nombre': 'Tracy Anderson',
#   'apellido': 'Barber',
#   'email': 'clittle@example.com',
#   'direccion': '37610 Dennis Fort\nNunezton, FM 90739'},
#  {'nombre': 'Kathryn Holmes',
#   'apellido': 'Garrett',
#   'email': 'tdixon@example.com',
#   'direccion': '412 Meyer Mission Apt. 536\nEast Jacobland, AZ 49160'},
#  {'nombre': 'Richard Odonnell',
#   'apellido': 'Beck',
#   'email': 'newtonedward@example.org',
#   'direccion': '67992 Gregory Hollow Apt. 029\nWellsmouth, ME 58676'},
#  {'nombre': 'Lisa Rodriguez',
#   'apellido': 'Arellano',
#   'email': 'cynthiahall@example.com',
#   'direccion': '508 Edwards Island\nSuzannechester, CA 47406'},
#  {'nombre': 'Sheryl Johnson',
#   'apellido': 'Stevens',
#   'email': 'michaelsampson@example.net',
#   'direccion': '2942 Richardson Plaza Suite 725\nEast Randall, OR 65180'},
#  {'nombre': 'Jeremy Carroll',
#   'apellido': 'Morrison',
#   'email': 'burgesscarmen@example.org',
#   'direccion': '820 Newton Flats Apt. 988\nBlackhaven, CT 88107'},
#  {'nombre': 'Kelsey Carr',
#   'apellido': 'Sims',
#   'email': 'luis41@example.org',
#   'direccion': '67136 Billy Cape\nLambertville, NC 40797'},
#  {'nombre': 'Paula Thomas',
#   'apellido': 'Gilmore',
#   'email': 'lori39@example.org',
#   'direccion': '17057 Parks Expressway\nNew Ryanville, AR 12339'},
#  {'nombre': 'Ryan Olson',
#   'apellido': 'Gonzalez',
#   'email': 'kelseyreid@example.net',
#   'direccion': '20257 Kyle Street\nMillerchester, AL 50266'},
#  {'nombre': 'John Underwood',
#   'apellido': 'Hickman',
#   'email': 'hannah23@example.net',
#   'direccion': '7529 Navarro Bridge Suite 683\nLake Trevor, UT 47644'},
#  {'nombre': 'Ashley Clarke',
#   'apellido': 'Velasquez',
#   'email': 'kibarra@example.com',
#   'direccion': '0947 Cook Valley\nDaltonbury, PW 35810'},
#  {'nombre': 'Gregory Brown',
#   'apellido': 'Evans',
#   'email': 'linda04@example.com',
#   'direccion': '694 Mclaughlin Summit Suite 617\nLake Thomasstad, LA 26171'},
#  {'nombre': 'Christine Harris',
#   'apellido': 'Wagner',
#   'email': 'pwhitehead@example.com',
#   'direccion': '742 Steven Crescent Apt. 454\nErinbury, AR 86154'},
#  {'nombre': 'Audrey Mccall',
#   'apellido': 'Johnson',
#   'email': 'mary47@example.org',
#   'direccion': '56356 Jacob Drive Suite 588\nNorth Stacey, KS 06804'},
#  {'nombre': 'Shannon Williams',
#   'apellido': 'Mclean',
#   'email': 'frobinson@example.net',
#   'direccion': '2553 Ernest Spring Suite 588\nPort Denise, IN 09345'},
#  {'nombre': 'Patricia Murphy',
#   'apellido': 'Baker',
#   'email': 'jasonsmith@example.com',
#   'direccion': '92218 Darren Extensions Suite 401\nYoungmouth, IA 25545'},
#  {'nombre': 'David Cole',
#   'apellido': 'Griffin',
#   'email': 'lisa17@example.com',
#   'direccion': '925 Fitzgerald Cove Apt. 576\nOlivertown, AL 61367'},
#  {'nombre': 'Sydney Downs DDS',
#   'apellido': 'Wilson',
#   'email': 'ijackson@example.com',
#   'direccion': '731 Albert Courts Suite 945\nNorth Angelicaburgh, IL 16507'},
#  {'nombre': 'David Hines',
#   'apellido': 'Massey',
#   'email': 'julianjohnson@example.net',
#   'direccion': 'Unit 3416 Box 4196\nDPO AP 64077'},
#  {'nombre': 'Alicia Winters',
#   'apellido': 'Hart',
#   'email': 'cbailey@example.com',
#   'direccion': '211 Haley Tunnel\nMitchellside, AR 35067'},
#  {'nombre': 'Andrea Lucas',
#   'apellido': 'Gonzalez',
#   'email': 'nicholas23@example.net',
#   'direccion': '05994 Bell Fields Apt. 509\nMackchester, VI 63599'},
#  {'nombre': 'Morgan Smith',
#   'apellido': 'Arias',
#   'email': 'campbellamber@example.com',
#   'direccion': 'Unit 0580 Box 8335\nDPO AP 79335'},
#  {'nombre': 'Robert Beasley',
#   'apellido': 'Manning',
#   'email': 'mtownsend@example.com',
#   'direccion': '66841 Cynthia Plain Apt. 366\nWest Ruth, NY 68108'},
#  {'nombre': 'Michael Davis',
#   'apellido': 'Rivera',
#   'email': 'sarah58@example.net',
#   'direccion': '29890 Holly Throughway\nWest Jennifer, RI 73726'},
#  {'nombre': 'Brooke Obrien',
#   'apellido': 'Fletcher',
#   'email': 'shelly71@example.org',
#   'direccion': '02301 Melissa Streets\nLisachester, WI 08911'},
#  {'nombre': 'Lauren Smith',
#   'apellido': 'Gibbs',
#   'email': 'paul55@example.com',
#   'direccion': '917 Brown Crossing Apt. 462\nNew Ashleyton, SD 56103'},
#  {'nombre': 'Erin Sharp',
#   'apellido': 'Sanders',
#   'email': 'hendersonbrandon@example.net',
#   'direccion': '05940 Morton Brooks Suite 953\nEast Tinaborough, NE 64206'},
#  {'nombre': 'Brenda Bentley',
#   'apellido': 'Marquez',
#   'email': 'adamsmark@example.com',
#   'direccion': '6157 Caroline Extension\nJamesside, PR 92142'},
#  {'nombre': 'Dakota Woodard',
#   'apellido': 'King',
#   'email': 'uneal@example.net',
#   'direccion': '071 Mcintyre Way Apt. 366\nBrianside, KY 80786'},
#  {'nombre': 'Benjamin Baker',
#   'apellido': 'Mendoza',
#   'email': 'katherinediaz@example.org',
#   'direccion': '6558 Chris Wells Apt. 543\nStevenhaven, RI 40340'},
#  {'nombre': 'Nicole Walker',
#   'apellido': 'Wang',
#   'email': 'rwebster@example.net',
#   'direccion': '0998 Stephen Lodge Apt. 719\nHayestown, ND 03445'},
#  {'nombre': 'Hayden Ruiz',
#   'apellido': 'Jenkins',
#   'email': 'michaelmckee@example.org',
#   'direccion': '4373 Nicole Courts Apt. 961\nPort Scottshire, AR 25499'},
#  {'nombre': 'Melissa Ray',
#   'apellido': 'Sanders',
#   'email': 'ricardobailey@example.net',
#   'direccion': 'Unit 7619 Box 2042\nDPO AP 34812'},
#  {'nombre': 'Brandon Kaiser',
#   'apellido': 'Simon',
#   'email': 'xjohnston@example.com',
#   'direccion': 'PSC 3479, Box 6885\nAPO AP 31536'},
#  {'nombre': 'Julia Thomas',
#   'apellido': 'Johnson',
#   'email': 'conleycody@example.org',
#   'direccion': 'PSC 9115, Box 5401\nAPO AP 16770'},
#  {'nombre': 'Kimberly Jimenez',
#   'apellido': 'Sanchez',
#   'email': 'smithjeffrey@example.net',
#   'direccion': '212 Gutierrez Stream Apt. 128\nSouth Jamesborough, MD 03397'},
#  {'nombre': 'Robin Fisher',
#   'apellido': 'Macias',
#   'email': 'aaron09@example.com',
#   'direccion': '53475 Taylor Terrace Suite 575\nRobertastad, MS 14045'},
#  {'nombre': 'Ryan Allen',
#   'apellido': 'Mcbride',
#   'email': 'whitakershelby@example.org',
#   'direccion': '960 Mccoy Mission\nFloresborough, AL 80806'},
#  {'nombre': 'Annette Lane',
#   'apellido': 'Davis',
#   'email': 'john85@example.org',
#   'direccion': '21477 Rich Estates Suite 942\nJessefort, KS 01338'},
#  {'nombre': 'Michael Flores',
#   'apellido': 'Cross',
#   'email': 'russellcollins@example.com',
#   'direccion': '353 Michael Union Apt. 958\nEast Susan, FL 69621'},
#  {'nombre': 'Sean Johnson',
#   'apellido': 'Ross',
#   'email': 'hallbrittany@example.net',
#   'direccion': '5137 Kevin Hills\nEast Howardside, PR 93882'},
#  {'nombre': 'Rachel Knight',
#   'apellido': 'Mendoza',
#   'email': 'oalexander@example.com',
#   'direccion': '325 Duran Village\nShawnside, RI 50142'},
#  {'nombre': 'John Barnett',
#   'apellido': 'Richard',
#   'email': 'nmeadows@example.net',
#   'direccion': '363 Patterson Parkway\nDeborahmouth, AZ 16108'},
#  {'nombre': 'Suzanne Fisher',
#   'apellido': 'Martinez',
#   'email': 'hdodson@example.net',
#   'direccion': 'Unit 1350 Box 5534\nDPO AP 58929'},
#  {'nombre': 'Dana Smith',
#   'apellido': 'Rice',
#   'email': 'angelwilliams@example.com',
#   'direccion': '3668 Barnett Harbor\nLake Holly, MP 34239'},
#  {'nombre': 'Stephen Rodriguez DVM',
#   'apellido': 'Allen',
#   'email': 'lutzjoseph@example.com',
#   'direccion': 'PSC 1854, Box 6673\nAPO AA 59617'},
#  {'nombre': 'Jeff Walker',
#   'apellido': 'Sawyer',
#   'email': 'wreid@example.com',
#   'direccion': 'USNS Rivera\nFPO AP 78268'},
#  {'nombre': 'Jennifer Wang',
#   'apellido': 'Gregory',
#   'email': 'samantha11@example.com',
#   'direccion': '750 Jesse Islands Suite 478\nLisaland, SD 97148'},
#  {'nombre': 'Latasha Long',
#   'apellido': 'Parks',
#   'email': 'jacktrujillo@example.com',
#   'direccion': 'PSC 7982, Box 0965\nAPO AE 88210'},
#  {'nombre': 'Jasmine Jones',
#   'apellido': 'Carter',
#   'email': 'manuelmanning@example.net',
#   'direccion': '4091 Margaret Square\nGabrielletown, MD 78514'},
#  {'nombre': 'Amber Ortega',
#   'apellido': 'Wells',
#   'email': 'mark28@example.net',
#   'direccion': 'PSC 6472, Box 1647\nAPO AP 12319'},
#  {'nombre': 'Patricia King',
#   'apellido': 'Charles',
#   'email': 'campbellthomas@example.com',
#   'direccion': '8020 Ellis Mills\nNorth Erichaven, DE 08309'},
#  {'nombre': 'Amy Davis',
#   'apellido': 'Garza',
#   'email': 'fmiller@example.org',
#   'direccion': '080 Jackson Motorway\nMcfarlandton, MT 53329'},
#  {'nombre': 'Regina Hill',
#   'apellido': 'Bailey',
#   'email': 'cortiz@example.net',
#   'direccion': '218 Walker Mountains Apt. 323\nNew Tomstad, NC 77984'},
#  {'nombre': 'Wendy Hughes',
#   'apellido': 'Green',
#   'email': 'adamthompson@example.net',
#   'direccion': '608 Dean Lane\nShirleyhaven, AZ 09694'},
#  {'nombre': 'Sara White',
#   'apellido': 'Valdez',
#   'email': 'terrancecross@example.org',
#   'direccion': '26076 Fitzgerald Islands Apt. 518\nYoungbury, TX 25196'},
#  {'nombre': 'Kelsey Santiago',
#   'apellido': 'Anderson',
#   'email': 'danielbowen@example.com',
#   'direccion': '794 Morales Stream Suite 279\nJerrymouth, UT 79390'},
#  {'nombre': 'Crystal Smith',
#   'apellido': 'Valdez',
#   'email': 'ryanmartinez@example.com',
#   'direccion': '5510 Edwards Fords\nPort Samantha, VI 60001'},
#  {'nombre': 'Jermaine Reeves',
#   'apellido': 'Thompson',
#   'email': 'pmartin@example.com',
#   'direccion': 'PSC 7044, Box 0478\nAPO AP 13589'},
#  {'nombre': 'Caroline Sims',
#   'apellido': 'Levy',
#   'email': 'floresjames@example.net',
#   'direccion': 'Unit 4296 Box 7246\nDPO AA 62052'},
#  {'nombre': 'Kathy Watson',
#   'apellido': 'Baldwin',
#   'email': 'dicksondevin@example.org',
#   'direccion': '86800 Williams Mountains Apt. 602\nWest Kristinfort, DE 79963'},
#  {'nombre': 'James Morton',
#   'apellido': 'Rice',
#   'email': 'xpeterson@example.org',
#   'direccion': '4427 Smith Overpass\nRichardfurt, MN 49615'},
#  {'nombre': 'Kristin Castro',
#   'apellido': 'Ramos',
#   'email': 'gharper@example.org',
#   'direccion': '6444 Stuart Pines Suite 176\nNorth Vernon, NM 15395'},
#  {'nombre': 'Jason Bryan',
#   'apellido': 'White',
#   'email': 'xduffy@example.com',
#   'direccion': '21607 Jimmy Inlet\nEast Adamstad, TX 81406'},
#  {'nombre': 'Raymond Wright',
#   'apellido': 'Jones',
#   'email': 'katherinehodge@example.net',
#   'direccion': '2224 Hayden Port Apt. 603\nPort Amandaberg, MI 11481'},
#  {'nombre': 'Daniel Mcconnell',
#   'apellido': 'Hayes',
#   'email': 'valeriemullen@example.net',
#   'direccion': 'Unit 7491 Box 6591\nDPO AA 59392'},
#  {'nombre': 'Charles Brown',
#   'apellido': 'Vance',
#   'email': 'qevans@example.com',
#   'direccion': '023 Wood Square Suite 792\nSamanthastad, WY 40761'},
#  {'nombre': 'Jean Cook',
#   'apellido': 'Gonzales',
#   'email': 'uhampton@example.org',
#   'direccion': '77178 Jeffrey Radial Suite 488\nGomezmouth, NJ 04578'},
#  {'nombre': 'Kristen Stewart',
#   'apellido': 'Levy',
#   'email': 'johnsondanielle@example.org',
#   'direccion': '809 Ashley Inlet Apt. 257\nNorth Amber, AL 53341'},
#  {'nombre': 'Diana Rowland',
#   'apellido': 'Davis',
#   'email': 'michael97@example.net',
#   'direccion': '6004 Saunders Underpass Apt. 607\nSharonshire, NV 26579'},
#  {'nombre': 'Jason Lee',
#   'apellido': 'Jackson',
#   'email': 'singhashley@example.com',
#   'direccion': '60410 Ronald Canyon Apt. 582\nSouth Hannah, PW 63208'},
#  {'nombre': 'Lisa Avila',
#   'apellido': 'Oliver',
#   'email': 'tyler98@example.net',
#   'direccion': '9220 Wells Station Apt. 447\nRachelville, AK 63197'},
#  {'nombre': 'Pamela Thomas',
#   'apellido': 'Schroeder',
#   'email': 'jaimegarcia@example.com',
#   'direccion': '3495 Porter Bypass Suite 264\nWest Gabriela, WI 39139'},
#  {'nombre': 'Zachary Moore',
#   'apellido': 'Malone',
#   'email': 'christopher75@example.net',
#   'direccion': '82403 Wilkins Cape Apt. 437\nNew Chadburgh, NY 31813'},
#  {'nombre': 'Elizabeth Caldwell',
#   'apellido': 'Gaines',
#   'email': 'mary45@example.net',
#   'direccion': '706 Robert Fields Suite 258\nKellerview, TN 92622'},
#  {'nombre': 'Molly Mcmahon',
#   'apellido': 'Donovan',
#   'email': 'kblake@example.net',
#   'direccion': 'Unit 2326 Box 7014\nDPO AA 82399'},
#  {'nombre': 'Shaun Ball',
#   'apellido': 'Hardin',
#   'email': 'rrusso@example.net',
#   'direccion': '0884 Sarah Plains Suite 999\nSmithburgh, DC 74221'},
#  {'nombre': 'Angela Juarez',
#   'apellido': 'Horne',
#   'email': 'shortronald@example.org',
#   'direccion': '533 Gutierrez Grove Suite 778\nChasemouth, WA 08756'},
#  {'nombre': 'Matthew Hernandez',
#   'apellido': 'Davenport',
#   'email': 'joshuaortiz@example.net',
#   'direccion': '3485 Christine Spurs Suite 330\nRobinview, NE 25922'},
#  {'nombre': 'Alicia Jones',
#   'apellido': 'Miller',
#   'email': 'sarayang@example.org',
#   'direccion': '545 Clifford Shores\nHeiditown, WV 63664'},
#  {'nombre': 'Nancy Moore',
#   'apellido': 'Rivers',
#   'email': 'deanna78@example.com',
#   'direccion': '3117 Luna Isle\nGeorgefurt, DC 37638'},
#  {'nombre': 'Steven May',
#   'apellido': 'Durham',
#   'email': 'brenda70@example.com',
#   'direccion': '2100 Tyrone Mill Apt. 624\nGutierrezland, AL 49875'},
#  {'nombre': 'Mr. Ian Swanson',
#   'apellido': 'Le',
#   'email': 'anna55@example.com',
#   'direccion': '7495 Hampton Alley\nDennisfurt, MP 73105'},
#  {'nombre': 'Brian Becker',
#   'apellido': 'Harper',
#   'email': 'melanie67@example.org',
#   'direccion': '36736 Miller Burgs Suite 421\nRobertfurt, MA 83058'},
#  {'nombre': 'Stephanie Freeman',
#   'apellido': 'Goodman',
#   'email': 'sonyafuentes@example.org',
#   'direccion': '509 Howard Road\nEast Stephanie, PA 98764'},
#  {'nombre': 'Anita Reyes',
#   'apellido': 'Thompson',
#   'email': 'mendezemily@example.com',
#   'direccion': '38177 Rodriguez Stream Apt. 178\nPort Kyleland, ID 60099'},
#  {'nombre': 'Edward Thompson',
#   'apellido': 'Lewis',
#   'email': 'neil54@example.net',
#   'direccion': '521 Norton Gateway Suite 456\nMendezville, MI 91066'},
#  {'nombre': 'Tom Mcdonald',
#   'apellido': 'Aguilar',
#   'email': 'mcunningham@example.org',
#   'direccion': '5450 Johnson Lock\nEast Kaylamouth, MI 02508'},
#  {'nombre': 'Jeffrey Clayton',
#   'apellido': 'Anderson',
#   'email': 'espinozadaniel@example.org',
#   'direccion': '511 King Courts Suite 502\nPort David, CO 99079'},
#  {'nombre': 'Samantha Santana',
#   'apellido': 'Crawford',
#   'email': 'qcarey@example.net',
#   'direccion': '47315 Jackson Cape Apt. 572\nTinamouth, MN 35981'},
#  {'nombre': 'Matthew Stewart',
#   'apellido': 'Robertson',
#   'email': 'edwin10@example.net',
#   'direccion': '9993 Maynard Keys Apt. 613\nWhiteberg, ME 68450'},
#  {'nombre': 'Mary Mueller',
#   'apellido': 'Patterson',
#   'email': 'moniquebuckley@example.com',
#   'direccion': '000 Carl Pass\nWest Arthur, AK 22491'},
#  {'nombre': 'Rhonda Williamson',
#   'apellido': 'Harrell',
#   'email': 'sgarcia@example.com',
#   'direccion': '380 Watson Inlet Suite 329\nSouth Andrewside, NC 30068'},
#  {'nombre': 'Stacey Shepherd',
#   'apellido': 'Baker',
#   'email': 'jacob11@example.org',
#   'direccion': '219 Jessica Falls\nPort Aliceview, AR 15548'},
#  {'nombre': 'Becky Smith',
#   'apellido': 'Mata',
#   'email': 'pbarker@example.com',
#   'direccion': '6737 Katherine Brooks Suite 829\nSouth Williamtown, MO 36404'},
#  {'nombre': 'Scott Raymond',
#   'apellido': 'Johnson',
#   'email': 'andersonkelly@example.net',
#   'direccion': '93140 Cindy Shores Apt. 695\nEsparzafurt, FM 85037'},
#  {'nombre': 'Nathaniel Butler',
#   'apellido': 'Pham',
#   'email': 'ismith@example.net',
#   'direccion': '7349 Abbott Mills\nEast John, IA 32195'},
#  {'nombre': 'Luis Higgins',
#   'apellido': 'Walters',
#   'email': 'andrea63@example.com',
#   'direccion': '50509 Andrews Road\nSouth Kellystad, UT 01101'},
#  {'nombre': 'Christopher Ramirez',
#   'apellido': 'Holden',
#   'email': 'smithmeghan@example.com',
#   'direccion': '332 Ronald Brook\nMichelleport, ND 29881'},
#  {'nombre': 'Jason English',
#   'apellido': 'Gibson',
#   'email': 'erikarhodes@example.org',
#   'direccion': '7977 Robin Flats Suite 341\nPort Davidville, AS 38891'},
#  {'nombre': 'Dana Ortiz',
#   'apellido': 'Hanson',
#   'email': 'christinesmall@example.org',
#   'direccion': '5031 Joshua Estate Apt. 796\nNew Thomastown, AL 39977'},
#  {'nombre': 'Thomas Daniel',
#   'apellido': 'Alvarez',
#   'email': 'cody13@example.net',
#   'direccion': '61299 Alejandro Haven\nNorth Alexaville, NH 88647'},
#  {'nombre': 'Brian Hughes',
#   'apellido': 'Cummings',
#   'email': 'leonardrobert@example.org',
#   'direccion': 'Unit 7249 Box 3170\nDPO AA 89856'},
#  {'nombre': 'Kaitlyn Stevens',
#   'apellido': 'Williams',
#   'email': 'ureed@example.org',
#   'direccion': '61711 Erin Green Apt. 505\nObrienton, ND 93061'},
#  {'nombre': 'Jasmine Smith',
#   'apellido': 'Jones',
#   'email': 'ntaylor@example.com',
#   'direccion': '75835 Stephanie Center Apt. 286\nNorth Jonathanstad, TN 03730'},
#  {'nombre': 'Thomas Meyer',
#   'apellido': 'Brady',
#   'email': 'jenningsderrick@example.net',
#   'direccion': '3254 Brenda Place Suite 628\nNew Connorview, KS 25997'},
#  {'nombre': 'Timothy Daniels',
#   'apellido': 'Robertson',
#   'email': 'kimberlyjohnson@example.org',
#   'direccion': '46881 Jonathon Green\nMargarettown, TX 50157'},
#  {'nombre': 'Tina Jacobs',
#   'apellido': 'Wood',
#   'email': 'tsmith@example.com',
#   'direccion': '5906 Lewis Mount Suite 605\nWangview, DE 71505'},
#  {'nombre': 'Deborah Pierce',
#   'apellido': 'Gonzalez',
#   'email': 'kevin07@example.net',
#   'direccion': '037 Griffin Run\nBrownchester, WA 79818'},
#  {'nombre': 'Gerald Morgan PhD',
#   'apellido': 'Stewart',
#   'email': 'bryan18@example.com',
#   'direccion': 'Unit 2000 Box 9000\nDPO AP 13572'},
#  {'nombre': 'Mary Tapia',
#   'apellido': 'Morris',
#   'email': 'chadyoung@example.net',
#   'direccion': '54127 Susan Springs Apt. 200\nPort John, NH 09968'},
#  {'nombre': 'Daniel Jones',
#   'apellido': 'Zuniga',
#   'email': 'christinasharp@example.org',
#   'direccion': '90509 Steven Dam\nLynchburgh, FL 19073'},
#  {'nombre': 'Ryan Russo',
#   'apellido': 'Munoz',
#   'email': 'william47@example.net',
#   'direccion': '16742 Walker Avenue\nPort Andreamouth, ME 30296'},
#  {'nombre': 'Shelly Davis',
#   'apellido': 'Smith',
#   'email': 'dustinanderson@example.com',
#   'direccion': '839 Colleen Common\nHammondland, MT 91557'},
#  {'nombre': 'Brandon Long',
#   'apellido': 'Cole',
#   'email': 'rodney76@example.org',
#   'direccion': '30390 Larsen Inlet Apt. 269\nPearsonmouth, ID 74958'},
#  {'nombre': 'Alyssa Sims',
#   'apellido': 'Strickland',
#   'email': 'frodriguez@example.net',
#   'direccion': '99700 Julian Track Suite 933\nPort Spencerchester, VT 42240'},
#  {'nombre': 'Sara Butler',
#   'apellido': 'Mitchell',
#   'email': 'patrick86@example.com',
#   'direccion': '575 Ray Points\nStricklandville, WI 89417'},
#  {'nombre': 'Elizabeth Olson',
#   'apellido': 'Ingram',
#   'email': 'haysbrian@example.com',
#   'direccion': '796 Hill Pike\nBobbyville, ME 54926'},
#  {'nombre': 'Katherine Johnson',
#   'apellido': 'Price',
#   'email': 'davidbaker@example.net',
#   'direccion': '6327 Nicole Wall\nEast Robert, WI 86688'},
#  {'nombre': 'Jared Tanner',
#   'apellido': 'Garcia',
#   'email': 'rbaker@example.org',
#   'direccion': 'USNV Hurst\nFPO AP 88159'},
#  {'nombre': 'Jessica White',
#   'apellido': 'Webster',
#   'email': 'bryanconway@example.org',
#   'direccion': '782 Robert Street Suite 660\nNicholstown, ND 37309'},
#  {'nombre': 'Janet Lewis',
#   'apellido': 'May',
#   'email': 'djohnson@example.net',
#   'direccion': '740 Nicole Inlet\nLarryton, WV 46467'},
#  {'nombre': 'Mr. Douglas Daniel DDS',
#   'apellido': 'Garcia',
#   'email': 'nicolehart@example.org',
#   'direccion': '746 Brenda Estate Apt. 048\nLake Matthewland, MD 63652'},
#  {'nombre': 'Linda Leon',
#   'apellido': 'Smith',
#   'email': 'tomweaver@example.org',
#   'direccion': '6439 Terry Ports Suite 100\nNorth Nathan, MP 09768'},
#  {'nombre': 'Andrew Graham',
#   'apellido': 'Hanson',
#   'email': 'aliciahutchinson@example.com',
#   'direccion': '8630 Perez Crescent Suite 656\nWest Kenneth, CO 29440'},
#  {'nombre': 'Laura Jones',
#   'apellido': 'Brown',
#   'email': 'williamjohnson@example.com',
#   'direccion': '875 Michael Mall Suite 236\nEast Michelleborough, MS 93827'},
#  {'nombre': 'Kristin Murray',
#   'apellido': 'Smith',
#   'email': 'dawn96@example.org',
#   'direccion': '64592 Vasquez Valley Apt. 533\nSmithmouth, AS 09931'},
#  {'nombre': 'Cynthia Riley',
#   'apellido': 'Ramirez',
#   'email': 'wesley32@example.net',
#   'direccion': '85098 Ellis Trail Suite 445\nSouth Cynthiatown, KS 45331'},
#  {'nombre': 'Dan Rodriguez',
#   'apellido': 'Mitchell',
#   'email': 'carlos21@example.com',
#   'direccion': '789 Sherry Common Suite 956\nDeleonside, WA 82393'},
#  {'nombre': 'Chloe Anderson',
#   'apellido': 'Green',
#   'email': 'sgay@example.org',
#   'direccion': '6546 Taylor Garden Apt. 259\nNorth Amberchester, KS 72376'},
#  {'nombre': 'John Baker',
#   'apellido': 'Copeland',
#   'email': 'brice@example.net',
#   'direccion': '81637 Sean Court\nEast Elizabeth, NM 35877'},
#  {'nombre': 'Shannon Navarro',
#   'apellido': 'Jones',
#   'email': 'greenerachael@example.com',
#   'direccion': '60957 Vaughn Flats\nKarenberg, MD 68899'},
#  {'nombre': 'Jacob Martin',
#   'apellido': 'Frye',
#   'email': 'jacobtaylor@example.net',
#   'direccion': '236 Carter Brook Suite 326\nLake Lauraville, KY 89337'},
#  {'nombre': 'Scott Johnson',
#   'apellido': 'Ortiz',
#   'email': 'psanders@example.org',
#   'direccion': '782 Ralph Mountain\nSmithborough, MH 93877'},
#  {'nombre': 'Benjamin Miles',
#   'apellido': 'Garner',
#   'email': 'matthewhall@example.net',
#   'direccion': '774 Dennis Estates\nAlexandermouth, IA 58446'},
#  {'nombre': 'Jesus Garcia',
#   'apellido': 'Mclaughlin',
#   'email': 'turneralexander@example.net',
#   'direccion': '21084 Michaela Corners Apt. 656\nEast Thomas, MS 53487'},
#  {'nombre': 'Troy Jackson',
#   'apellido': 'Winters',
#   'email': 'josephdavis@example.org',
#   'direccion': '97971 Harvey Run Suite 011\nEdwinbury, MA 97111'},
#  {'nombre': 'Dwayne Barajas',
#   'apellido': 'Gonzales',
#   'email': 'vgomez@example.net',
#   'direccion': '08341 Linda Ramp\nStanleyton, MO 44845'},
#  {'nombre': 'Dana Ramos',
#   'apellido': 'Gaines',
#   'email': 'pjohnson@example.net',
#   'direccion': '1268 Jordan Lights Suite 305\nJacksonchester, PR 87071'},
#  {'nombre': 'Joshua Walker',
#   'apellido': 'Mason',
#   'email': 'wendylevy@example.com',
#   'direccion': '957 Norman Harbors Apt. 843\nPort Aimeeview, VA 65441'},
#  {'nombre': 'Donald Gonzalez',
#   'apellido': 'Lopez',
#   'email': 'karenhobbs@example.net',
#   'direccion': '009 Brown Centers Suite 047\nBethanyfurt, SC 20587'},
#  {'nombre': 'Stephanie Dominguez',
#   'apellido': 'Rivers',
#   'email': 'seandavies@example.com',
#   'direccion': '0284 Wallace Ridges\nLisaton, RI 21828'},
#  {'nombre': 'Teresa Parker',
#   'apellido': 'Gutierrez',
#   'email': 'julie37@example.com',
#   'direccion': '801 Johnson Plains Suite 605\nKarenshire, CO 21656'},
#  {'nombre': 'Jessica Hoffman',
#   'apellido': 'Sanchez',
#   'email': 'guzmanerica@example.org',
#   'direccion': '359 Fox Dam Suite 197\nPort Alexander, VT 82847'},
#  {'nombre': 'Ashley Ramos',
#   'apellido': 'Smith',
#   'email': 'stephenmendoza@example.net',
#   'direccion': '00582 Maria Burg\nJeremymouth, MI 47040'},
#  {'nombre': 'Leroy Fleming',
#   'apellido': 'Santiago',
#   'email': 'sarahpitts@example.org',
#   'direccion': '0619 Julia Crossing Suite 545\nNorth Carlos, AS 31613'},
#  {'nombre': 'Michael Fernandez',
#   'apellido': 'Stokes',
#   'email': 'curtis36@example.com',
#   'direccion': 'USNS Wiggins\nFPO AA 78502'},
#  {'nombre': 'Rodney Saunders',
#   'apellido': 'Watson',
#   'email': 'angela08@example.com',
#   'direccion': '62189 Dylan Branch\nWilsonchester, OH 85906'},
#  {'nombre': 'Tara Reed',
#   'apellido': 'Turner',
#   'email': 'drodriguez@example.net',
#   'direccion': '9823 Garcia Manors\nPort Matthewburgh, MO 06074'},
#  {'nombre': 'Sarah Castillo',
#   'apellido': 'Powell',
#   'email': 'finleyhannah@example.net',
#   'direccion': '93420 Rose Pines Suite 890\nLisaton, ME 53686'},
#  {'nombre': 'Lisa Rogers',
#   'apellido': 'Harper',
#   'email': 'wmcmillan@example.net',
#   'direccion': '50019 Brian Center\nNorth Melanie, TN 11246'},
#  {'nombre': 'Samantha Stone',
#   'apellido': 'Colon',
#   'email': 'fishererica@example.net',
#   'direccion': '24602 Wallace Manors\nScottton, MO 86241'},
#  {'nombre': 'Benjamin Stevens',
#   'apellido': 'Jones',
#   'email': 'rharris@example.com',
#   'direccion': '5226 Liu Fork Suite 539\nEast Tiffanyville, IA 65032'},
#  {'nombre': 'Shannon Smith',
#   'apellido': 'Moyer',
#   'email': 'lucasdavid@example.net',
#   'direccion': '83381 Ortiz Mountains\nEast Robertoshire, VI 65939'},
#  {'nombre': 'Sharon Maynard',
#   'apellido': 'Smith',
#   'email': 'dshelton@example.net',
#   'direccion': 'Unit 1264 Box 1380\nDPO AE 25459'},
#  {'nombre': 'Jordan Reid',
#   'apellido': 'French',
#   'email': 'gmartinez@example.net',
#   'direccion': '96443 Daniel Burg Apt. 278\nPort Jorgefurt, CT 42633'},
#  {'nombre': 'Michelle Wu',
#   'apellido': 'Welch',
#   'email': 'gthomas@example.com',
#   'direccion': 'PSC 7333, Box 7386\nAPO AE 72592'},
#  {'nombre': 'Andrea Nash',
#   'apellido': 'Hill',
#   'email': 'gregharper@example.com',
#   'direccion': '233 Gibson Stravenue Apt. 200\nNorth Jamesland, GU 26910'},
#  {'nombre': 'James Lewis',
#   'apellido': 'Garcia',
#   'email': 'qwhite@example.com',
#   'direccion': '296 Heather Lock\nBarbaraland, MN 20781'},
#  {'nombre': 'Gabriel Ramos',
#   'apellido': 'Lee',
#   'email': 'brooksheather@example.org',
#   'direccion': '73084 Thompson Keys\nPort Troyton, SD 82759'},
#  {'nombre': 'David Sawyer',
#   'apellido': 'Chapman',
#   'email': 'harrisalbert@example.com',
#   'direccion': '100 Cheryl Creek Suite 244\nLake Todd, PR 80586'},
#  {'nombre': 'Karen Boyd',
#   'apellido': 'Hodge',
#   'email': 'jeffreyprince@example.com',
#   'direccion': '7746 Allen Manor Apt. 372\nEast Daltonhaven, MA 92614'},
#  {'nombre': 'Renee Callahan',
#   'apellido': 'Bray',
#   'email': 'millermatthew@example.com',
#   'direccion': '2620 Michelle Stream\nMaryshire, NM 92844'},
#  {'nombre': 'Jessica Brooks',
#   'apellido': 'Brown',
#   'email': 'janetvargas@example.com',
#   'direccion': '131 Krueger Cape\nEricaberg, IN 70747'},
#  {'nombre': 'Sharon Austin',
#   'apellido': 'Johnson',
#   'email': 'debbie86@example.com',
#   'direccion': '967 Sharon Crossing Apt. 560\nSouth Juanmouth, OK 24862'},
#  {'nombre': 'Monica Reese',
#   'apellido': 'Fisher',
#   'email': 'nathanielsandoval@example.org',
#   'direccion': '067 Thomas Vista\nCampbellmouth, MT 91609'},
#  {'nombre': 'Eric Jones',
#   'apellido': 'Rivera',
#   'email': 'wmaxwell@example.org',
#   'direccion': '29269 Paula Trail\nBrookemouth, MN 01875'},
#  {'nombre': 'Kimberly Carr',
#   'apellido': 'Wolfe',
#   'email': 'wheelerelizabeth@example.net',
#   'direccion': '31939 Brown Bypass Apt. 484\nNew Sarah, NH 45839'},
#  {'nombre': 'Amanda Wilson',
#   'apellido': 'Anderson',
#   'email': 'uclark@example.org',
#   'direccion': '00995 Miller Ramp Apt. 598\nWest Victoria, DC 32333'},
#  {'nombre': 'Mark Yates',
#   'apellido': 'Harper',
#   'email': 'abbottalexis@example.com',
#   'direccion': 'PSC 0697, Box 5833\nAPO AP 62257'},
#  {'nombre': 'Holly Williams',
#   'apellido': 'Glenn',
#   'email': 'jerrylopez@example.com',
#   'direccion': '857 Corey Run Suite 620\nNew Frederickchester, MT 15327'},
#  {'nombre': 'Alex Ford',
#   'apellido': 'Weber',
#   'email': 'maxwellelijah@example.com',
#   'direccion': '3345 Carol Creek Apt. 336\nNew Katherinefort, NH 86925'},
#  {'nombre': 'Barbara Snyder',
#   'apellido': 'Marquez',
#   'email': 'wgreen@example.com',
#   'direccion': '9003 Sarah Manor Suite 156\nWest Robertfurt, NV 04098'},
#  {'nombre': 'Derek Simpson',
#   'apellido': 'Melton',
#   'email': 'josebrown@example.net',
#   'direccion': '215 Justin Lakes\nPort Adamhaven, AS 58070'},
#  {'nombre': 'Denise Miller',
#   'apellido': 'Smith',
#   'email': 'karenrogers@example.org',
#   'direccion': '269 Strong Springs\nElliotthaven, MS 92276'},
#  {'nombre': 'Robert Gibson',
#   'apellido': 'Cortez',
#   'email': 'jeff54@example.net',
#   'direccion': 'USNS Harrison\nFPO AE 84833'},
#  {'nombre': 'Joshua Ellison',
#   'apellido': 'Snyder',
#   'email': 'jerrystevens@example.com',
#   'direccion': '62869 Phillips Vista\nSouth Nicholasmouth, VT 82130'},
#  {'nombre': 'Timothy Schmidt',
#   'apellido': 'Doyle',
#   'email': 'ospencer@example.org',
#   'direccion': '661 Hudson Summit Suite 824\nSouth Barbara, AS 59582'},
#  {'nombre': 'John Wallace',
#   'apellido': 'Walker',
#   'email': 'heatherday@example.net',
#   'direccion': '158 Eric Course\nLake Saraside, VA 31619'},
#  {'nombre': 'Paul Aguilar',
#   'apellido': 'Powers',
#   'email': 'elizabeth62@example.com',
#   'direccion': '7043 Spence Park\nWest Marymouth, LA 58571'},
#  {'nombre': 'Daniel Wells',
#   'apellido': 'Daniel',
#   'email': 'richard42@example.org',
#   'direccion': '581 Garcia Walk Apt. 544\nWilliamsstad, NY 66985'},
#  {'nombre': 'Andrew Gibson',
#   'apellido': 'Thomas',
#   'email': 'erica03@example.net',
#   'direccion': 'PSC 4540, Box 7303\nAPO AP 11854'},
#  {'nombre': 'Robin Cox',
#   'apellido': 'Caldwell',
#   'email': 'monique59@example.com',
#   'direccion': '8042 Maureen Courts Suite 960\nLoriside, NH 19895'},
#  {'nombre': 'Patricia Vasquez',
#   'apellido': 'Holt',
#   'email': 'lauriearmstrong@example.net',
#   'direccion': '93989 Micheal Burgs\nNew Danielfurt, AZ 99887'},
#  {'nombre': 'Betty Davis',
#   'apellido': 'Jefferson',
#   'email': 'egonzales@example.net',
#   'direccion': '3887 Roberts Island Apt. 830\nNorth Amyburgh, MD 45625'},
#  {'nombre': 'Pam Johnson',
#   'apellido': 'Martinez',
#   'email': 'thomas41@example.net',
#   'direccion': 'Unit 6796 Box 3305\nDPO AE 18868'},
#  {'nombre': 'Kyle Gibbs',
#   'apellido': 'Hernandez',
#   'email': 'loganmarie@example.org',
#   'direccion': '1394 Brandon Greens\nSouth Amandafurt, FL 01813'},
#  {'nombre': 'Megan Trevino',
#   'apellido': 'Lee',
#   'email': 'meyerswilliam@example.net',
#   'direccion': 'Unit 7336 Box 4660\nDPO AP 31705'},
#  {'nombre': 'Karen Roberson',
#   'apellido': 'Nixon',
#   'email': 'millermichael@example.com',
#   'direccion': '792 Larry Harbor Suite 220\nRichardhaven, MO 53293'},
#  {'nombre': 'Johnny Taylor',
#   'apellido': 'Newman',
#   'email': 'victoriajones@example.net',
#   'direccion': '4268 Dustin Light Suite 519\nNorth Kelly, LA 25952'},
#  {'nombre': 'Tabitha Sutton',
#   'apellido': 'Taylor',
#   'email': 'zmartin@example.net',
#   'direccion': '09501 Adriana Corner Apt. 930\nCoreyfort, GA 19747'},
#  {'nombre': 'Denise Chapman',
#   'apellido': 'Flores',
#   'email': 'rsantana@example.org',
#   'direccion': '874 Cordova Junction Suite 314\nPort Amy, MH 42402'},
#  {'nombre': 'David Robertson',
#   'apellido': 'Knight',
#   'email': 'bridgesjesse@example.com',
#   'direccion': '12696 Laura Extensions Suite 837\nCannonberg, AS 23637'},
#  {'nombre': 'Christopher Brown',
#   'apellido': 'Delacruz',
#   'email': 'lisa36@example.com',
#   'direccion': 'PSC 8137, Box 2160\nAPO AP 86331'},
#  {'nombre': 'Eric Fox',
#   'apellido': 'Maynard',
#   'email': 'ryanrichardson@example.net',
#   'direccion': '3067 Dustin Passage\nNorth Tara, PR 90875'},
#  {'nombre': 'Johnny Miller',
#   'apellido': 'Bennett',
#   'email': 'huntermaxwell@example.net',
#   'direccion': '45401 Angela Centers\nLake Lisamouth, WI 65648'},
#  {'nombre': 'Gregory Ferguson',
#   'apellido': 'Parker',
#   'email': 'amy81@example.net',
#   'direccion': '3589 Sharon Square\nRodriguezview, IN 57638'},
#  {'nombre': 'Jeffrey Thompson',
#   'apellido': 'Hoover',
#   'email': 'chandlerstacey@example.com',
#   'direccion': '5223 Randall Mountain Apt. 515\nNew Vanessa, IA 30144'},
#  {'nombre': 'Jason Thompson MD',
#   'apellido': 'Randall',
#   'email': 'travisjohn@example.org',
#   'direccion': '4401 Suzanne Common Apt. 100\nKellychester, DC 95607'},
#  {'nombre': 'Matthew Roberts',
#   'apellido': 'Nolan',
#   'email': 'kurt21@example.com',
# ...
#   'direccion': 'USNS Pollard\nFPO AA 79691'},
#  {'nombre': 'Jonathan Boyd',
#   'apellido': 'Sandoval',
#   'email': 'gomezethan@example.com',
#   'direccion': '6136 Matthew Lodge\nCherylland, ME 74485'},
#  {'nombre': 'Luis Anderson',
#   'apellido': 'Kidd',
#   'email': 'josenovak@example.org',
#   'direccion': '4244 Erika Villages Apt. 638\nJosephview, WV 54820'},
#  {'nombre': 'Andrea Caldwell',
#   'apellido': 'Martin',
#   'email': 'jasonwilliams@example.net',
#   'direccion': '730 Walker Crossing Suite 544\nKevinburgh, MS 46873'},
#  {'nombre': 'Blake Gonzalez',
#   'apellido': 'Williams',
#   'email': 'johnsonjohn@example.net',
#   'direccion': '132 Bryant Tunnel\nLake Marc, NE 98327'},
#  {'nombre': 'Jermaine Smith',
#   'apellido': 'Lewis',
#   'email': 'jerrythompson@example.com',
#   'direccion': '0476 Reyes Squares\nWest Lisa, NM 41997'},
#  {'nombre': 'Ashley Guzman',
#   'apellido': 'Martinez',
#   'email': 'scottalicia@example.com',
#   'direccion': '09896 Judith Hollow\nLake Justinshire, PW 77224'},
#  {'nombre': 'Anthony Jones',
#   'apellido': 'Carter',
#   'email': 'lisathomas@example.net',
#   'direccion': '05360 Dawn Burgs\nSouth Conniefort, FL 81573'},
#  {'nombre': 'James Hoffman',
#   'apellido': 'Martin',
#   'email': 'kristina52@example.net',
#   'direccion': '544 Alexander Route Apt. 714\nLake Jacqueline, WY 92660'},
#  {'nombre': 'Dr. Jessica Taylor',
#   'apellido': 'Collins',
#   'email': 'elizabeth72@example.net',
#   'direccion': '2495 Nicholas Unions\nWest Jonathanshire, VA 90597'},
#  {'nombre': 'Justin Castro',
#   'apellido': 'Combs',
#   'email': 'laura69@example.net',
#   'direccion': 'Unit 9968 Box 3543\nDPO AA 25597'},
#  {'nombre': 'Maria Warren',
#   'apellido': 'Hopkins',
#   'email': 'hamiltonmonique@example.org',
#   'direccion': 'USNV Rodriguez\nFPO AE 44135'},
#  {'nombre': 'Margaret Moore',
#   'apellido': 'Daniels',
#   'email': 'christopher70@example.net',
#   'direccion': '13373 Harris Junction\nLoveton, AK 69089'},
#  {'nombre': 'Michele Chapman',
#   'apellido': 'Waters',
#   'email': 'jhughes@example.net',
#   'direccion': '251 Fletcher Ferry\nJessicaview, WY 04894'},
#  {'nombre': 'William Fox',
#   'apellido': 'Moore',
#   'email': 'ryan16@example.net',
#   'direccion': '4531 Crystal Shoal\nFrazierland, IA 53913'},
#  {'nombre': 'Ryan Carter MD',
#   'apellido': 'Gomez',
#   'email': 'wgarrett@example.com',
#   'direccion': '440 Felicia Meadow\nSouth Mariaburgh, WY 47022'},
#  {'nombre': 'Antonio Hudson',
#   'apellido': 'Diaz',
#   'email': 'gary23@example.org',
#   'direccion': '390 Guzman Ports Apt. 438\nChambersbury, WY 66553'},
#  {'nombre': 'Sarah Coleman',
#   'apellido': 'Wilson',
#   'email': 'garciawilliam@example.com',
#   'direccion': '00737 Wanda Key\nBrownberg, PA 90240'},
#  {'nombre': 'Amber Simmons MD',
#   'apellido': 'Hodges',
#   'email': 'ctaylor@example.org',
#   'direccion': 'PSC 7258, Box 2550\nAPO AA 85847'},
#  {'nombre': 'Bonnie Walker',
#   'apellido': 'Lyons',
#   'email': 'jonathonrichards@example.net',
#   'direccion': '849 Christopher Run Suite 015\nScottmouth, MO 63827'},
#  {'nombre': 'Lauren Osborne',
#   'apellido': 'Jones',
#   'email': 'amy85@example.net',
#   'direccion': '49857 Pollard Path Apt. 345\nNorth Jonathanhaven, GU 16742'},
#  {'nombre': 'Julie Hunt',
#   'apellido': 'Horn',
#   'email': 'nelsonnatalie@example.com',
#   'direccion': '6383 Erika Isle Apt. 117\nJenkinsshire, IL 30235'},
#  {'nombre': 'Benjamin Robertson',
#   'apellido': 'Smith',
#   'email': 'gabriella71@example.org',
#   'direccion': '133 Gabrielle Wells Apt. 273\nPort Shawnfort, MI 07171'},
#  {'nombre': 'Sarah Ross',
#   'apellido': 'Anderson',
#   'email': 'rodneyshelton@example.org',
#   'direccion': '252 Kimberly Greens\nNew Jasonchester, KS 65509'},
#  {'nombre': 'George Franklin',
#   'apellido': 'Kirk',
#   'email': 'alyssa55@example.com',
#   'direccion': '27765 Johnson Plains Suite 716\nRaymondville, NJ 92658'},
#  {'nombre': 'Stephen Stevens',
#   'apellido': 'Rivera',
#   'email': 'huffcheryl@example.org',
#   'direccion': '68286 Erica Ford Suite 833\nCoreyland, CA 57958'},
#  {'nombre': 'Cynthia Jones',
#   'apellido': 'Perez',
#   'email': 'mburton@example.net',
#   'direccion': 'USNS Bryan\nFPO AE 83490'},
#  {'nombre': 'Mallory Johnson',
#   'apellido': 'Payne',
#   'email': 'aaron50@example.net',
#   'direccion': '594 Barnes Light\nNew Barryhaven, AS 58132'},
#  {'nombre': 'Wendy Wells',
#   'apellido': 'Logan',
#   'email': 'janet44@example.org',
#   'direccion': '4659 Padilla Key Suite 743\nEricaland, NE 43059'},
#  {'nombre': 'Christina Barajas',
#   'apellido': 'Wilcox',
#   'email': 'brendaanderson@example.org',
#   'direccion': '93823 Craig Turnpike Apt. 504\nEdwardsbury, TN 51946'},
#  {'nombre': 'Jacob Morgan',
#   'apellido': 'Collins',
#   'email': 'aaronlawrence@example.com',
#   'direccion': '6811 Peterson Turnpike Apt. 875\nNorth Keith, OH 48161'},
#  {'nombre': 'Teresa Holt',
#   'apellido': 'Olson',
#   'email': 'clopez@example.net',
#   'direccion': 'Unit 2970 Box 2671\nDPO AP 18922'},
#  {'nombre': 'Danielle King',
#   'apellido': 'Cuevas',
#   'email': 'nicholas95@example.org',
#   'direccion': 'PSC 0802, Box 7362\nAPO AP 36246'},
#  {'nombre': 'April Scott',
#   'apellido': 'Duncan',
#   'email': 'ijohnson@example.org',
#   'direccion': '03287 Gordon Cliffs Suite 571\nNorth Daniel, KY 93413'},
#  {'nombre': 'Michael Chavez',
#   'apellido': 'Cooley',
#   'email': 'cmartin@example.net',
#   'direccion': '43272 Felicia Fall Apt. 636\nJoshualand, NY 48578'},
#  {'nombre': 'Robert Page',
#   'apellido': 'Reyes',
#   'email': 'austinmalik@example.org',
#   'direccion': '638 Hartman Street\nPort Belindabury, NM 10147'},
#  {'nombre': 'Susan Williams',
#   'apellido': 'Farmer',
#   'email': 'lucasrivera@example.net',
#   'direccion': '3521 Chase Ville\nTinaside, GU 66006'},
#  {'nombre': 'Karen Davis',
#   'apellido': 'Rich',
#   'email': 'zevans@example.com',
#   'direccion': 'USS Miranda\nFPO AP 84461'},
#  {'nombre': 'Megan Williams',
#   'apellido': 'Montgomery',
#   'email': 'hevans@example.org',
#   'direccion': '05355 Jacqueline Pines Apt. 344\nSaundersport, MA 79836'},
#  {'nombre': 'Stephen Mckee',
#   'apellido': 'Gilbert',
#   'email': 'chasebenjamin@example.org',
#   'direccion': '261 Burton Plains\nPriceland, CO 65375'},
#  {'nombre': 'James Black',
#   'apellido': 'Meza',
#   'email': 'jasonvelazquez@example.com',
#   'direccion': '890 Greg Cape\nNew Katie, OH 90570'},
#  {'nombre': 'Christopher Adams',
#   'apellido': 'Brown',
#   'email': 'marilynrussell@example.org',
#   'direccion': '2558 Chad Mews Suite 718\nSouth Alexandermouth, AR 85673'},
#  {'nombre': 'Tyler Ruiz',
#   'apellido': 'Dalton',
#   'email': 'gomezvincent@example.org',
#   'direccion': '87308 Kimberly Circles Apt. 729\nWelchborough, GA 29380'},
#  {'nombre': 'Jennifer Miller',
#   'apellido': 'Lyons',
#   'email': 'xbarron@example.org',
#   'direccion': 'USS Gould\nFPO AP 20135'},
#  {'nombre': 'Charles Carter',
#   'apellido': 'Gaines',
#   'email': 'brian63@example.com',
#   'direccion': '72393 Shannon Knoll\nEast Kennethville, TX 36120'},
#  {'nombre': 'Sandra Wilson',
#   'apellido': 'Murphy',
#   'email': 'lbernard@example.org',
#   'direccion': 'PSC 7688, Box 8188\nAPO AA 76625'},
#  {'nombre': 'Chase Peterson',
#   'apellido': 'Diaz',
#   'email': 'alexacurry@example.com',
#   'direccion': '65588 Smith Spurs\nEast Lindseyberg, HI 93833'},
#  {'nombre': 'Cheryl Walker',
#   'apellido': 'Foster',
#   'email': 'rosalesbrandon@example.net',
#   'direccion': '4709 Taylor Heights Apt. 032\nHaroldland, FM 47660'},
#  {'nombre': 'Jeffrey Martinez',
#   'apellido': 'Mckinney',
#   'email': 'davidbailey@example.com',
#   'direccion': '950 Richard Harbor Apt. 084\nPort Michael, IN 19908'},
#  {'nombre': 'Clayton White',
#   'apellido': 'Burton',
#   'email': 'dedwards@example.net',
#   'direccion': '98518 Edwards Ramp\nWest Sydneystad, GU 31515'},
#  {'nombre': 'Jessica Patrick',
#   'apellido': 'Reeves',
#   'email': 'destinymullins@example.net',
#   'direccion': '722 Smith Courts\nMeyerport, NE 47785'},
#  {'nombre': 'Thomas Thornton',
#   'apellido': 'Anderson',
#   'email': 'ravenmoore@example.org',
#   'direccion': '621 Susan Mount\nSouth Jacobhaven, PW 59986'},
#  {'nombre': 'Melissa Tate',
#   'apellido': 'Caldwell',
#   'email': 'matthewwest@example.net',
#   'direccion': '2279 Bishop Plains Suite 622\nSilvahaven, SD 76581'},
#  {'nombre': 'Janice Kim',
#   'apellido': 'Perkins',
#   'email': 'benjaminyoung@example.org',
#   'direccion': '46524 Johnson Trace Suite 269\nTimothyview, AS 66569'},
#  {'nombre': 'Ryan Robertson',
#   'apellido': 'Miller',
#   'email': 'robertsaunders@example.net',
#   'direccion': '613 Elizabeth Groves Apt. 608\nWest Michael, AZ 78280'},
#  {'nombre': 'Juan Evans',
#   'apellido': 'Miranda',
#   'email': 'rachel79@example.org',
#   'direccion': '876 Sara Green\nLake Vanessaburgh, AK 08898'},
#  {'nombre': 'Teresa Byrd',
#   'apellido': 'Bond',
#   'email': 'wendy97@example.com',
#   'direccion': '42946 Carpenter Neck Suite 583\nWalkerport, SD 84249'},
#  {'nombre': 'Michael Baker',
#   'apellido': 'Saunders',
#   'email': 'joseph88@example.net',
#   'direccion': '62167 Gene Orchard\nWest Samuel, VI 42533'},
#  {'nombre': 'Angel Robbins',
#   'apellido': 'Bailey',
#   'email': 'edwardharvey@example.com',
#   'direccion': '758 Michelle Roads\nPort Anthony, NY 52464'},
#  {'nombre': 'Tony Robinson',
#   'apellido': 'Rodriguez',
#   'email': 'michaelellis@example.org',
#   'direccion': '537 Manning Prairie\nAlvarezchester, PA 97063'},
#  {'nombre': 'Carla Williamson',
#   'apellido': 'Martinez',
#   'email': 'jennifer01@example.net',
#   'direccion': '30963 Jessica Tunnel Suite 027\nDennisburgh, OR 71411'},
#  {'nombre': 'Lindsey Garcia',
#   'apellido': 'Alexander',
#   'email': 'schmidtmichele@example.com',
#   'direccion': '54203 Tucker Course\nWest Tammy, MT 42794'},
#  {'nombre': 'Brenda Davis',
#   'apellido': 'Sparks',
#   'email': 'jamiewilliams@example.com',
#   'direccion': '856 Flores Trail Suite 465\nSabrinaside, NJ 92008'},
#  {'nombre': 'Matthew Williams',
#   'apellido': 'Guerrero',
#   'email': 'xrodriguez@example.com',
#   'direccion': '92341 Miller Spring Suite 473\nNorth David, NE 16949'},
#  {'nombre': 'Erin Carlson',
#   'apellido': 'Richardson',
#   'email': 'xthompson@example.com',
#   'direccion': 'PSC 2925, Box 4398\nAPO AP 04124'},
#  {'nombre': 'Christopher Nguyen',
#   'apellido': 'Lyons',
#   'email': 'kwilliams@example.org',
#   'direccion': '8593 Cabrera Canyon\nMaldonadobury, NC 98821'},
#  {'nombre': 'Jennifer Diaz MD',
#   'apellido': 'Smith',
#   'email': 'edwardskyle@example.com',
#   'direccion': '782 Crystal Garden\nJenkinsfurt, GA 95012'},
#  {'nombre': 'Julie Ward',
#   'apellido': 'Coleman',
#   'email': 'qhamilton@example.com',
#   'direccion': '0996 Kayla Tunnel\nNorth Kellychester, GU 38489'},
#  {'nombre': 'Melissa Goodman',
#   'apellido': 'Duffy',
#   'email': 'ysmith@example.org',
#   'direccion': 'Unit 0889 Box 7625\nDPO AP 97625'},
#  {'nombre': 'Samantha Lewis',
#   'apellido': 'Powers',
#   'email': 'jenniferflores@example.com',
#   'direccion': '20089 Rachel Roads\nNorth Emmahaven, MT 10849'},
#  {'nombre': 'Adrian Williams',
#   'apellido': 'Johnson',
#   'email': 'cameronthompson@example.com',
#   'direccion': '9593 Johnson Lakes\nWest Kristina, AR 98342'},
#  {'nombre': 'Abigail Logan DDS',
#   'apellido': 'Ramos',
#   'email': 'ramoscarlos@example.com',
#   'direccion': '79766 Stephanie Roads Apt. 009\nAnthonyton, SD 45708'},
#  {'nombre': 'Elizabeth Briggs',
#   'apellido': 'Burch',
#   'email': 'loribrown@example.com',
#   'direccion': '99606 Cross Row Suite 061\nNorth Jonathan, TX 26041'},
#  {'nombre': 'Mark Brown',
#   'apellido': 'Nunez',
#   'email': 'bartondavid@example.org',
#   'direccion': 'USCGC Sexton\nFPO AE 95701'},
#  {'nombre': 'Richard Durham',
#   'apellido': 'Brady',
#   'email': 'crystal44@example.org',
#   'direccion': '98235 Shaw Street\nWest Rebecca, NH 96683'},
#  {'nombre': 'Victoria Hernandez',
#   'apellido': 'Ayala',
#   'email': 'joshuachan@example.org',
#   'direccion': '38556 Jacob Curve Suite 434\nRamirezbury, FM 16233'},
#  {'nombre': 'Alex Brooks',
#   'apellido': 'Koch',
#   'email': 'cathy68@example.com',
#   'direccion': '863 Wiley Rue\nWest Elizabethton, HI 44019'},
#  {'nombre': 'Jennifer Owens',
#   'apellido': 'Adams',
#   'email': 'douglasbaker@example.org',
#   'direccion': '8157 Kyle Land Suite 550\nDawnton, WI 50156'},
#  {'nombre': 'Abigail Buckley',
#   'apellido': 'Smith',
#   'email': 'rboone@example.com',
#   'direccion': '0805 Elijah Spring Apt. 703\nGeorgeberg, NM 69654'},
#  {'nombre': 'Tina Hicks',
#   'apellido': 'Smith',
#   'email': 'martinezamanda@example.net',
#   'direccion': '948 Carol Estate\nLake Lisa, NC 20117'},
#  {'nombre': 'James Combs',
#   'apellido': 'Rogers',
#   'email': 'matthewbartlett@example.net',
#   'direccion': '493 White Stravenue Suite 664\nAndrewsview, CT 06261'},
#  {'nombre': 'Jennifer Stuart',
#   'apellido': 'Anderson',
#   'email': 'perkinsmichael@example.org',
#   'direccion': '296 Fowler Ports\nStephaniestad, IN 52205'},
#  {'nombre': 'Curtis Ross',
#   'apellido': 'Scott',
#   'email': 'carrillojonathan@example.net',
#   'direccion': 'Unit 5893 Box 0513\nDPO AA 11352'},
#  {'nombre': 'Cathy Fuller',
#   'apellido': 'Grant',
#   'email': 'stephanie88@example.net',
#   'direccion': '71771 Smith Lodge\nJoelburgh, MT 70789'},
#  {'nombre': 'Danielle Patel',
#   'apellido': 'Gordon',
#   'email': 'morganjoy@example.com',
#   'direccion': '01647 William Way\nPort Edward, WV 59505'},
#  {'nombre': 'Kyle Alvarado',
#   'apellido': 'Wright',
#   'email': 'willischristopher@example.org',
#   'direccion': '900 Hawkins Rest\nNew Lorimouth, NH 63627'},
#  {'nombre': 'Kathleen Martin',
#   'apellido': 'Beltran',
#   'email': 'nicole18@example.org',
#   'direccion': '1653 Perez Lights\nLake Ashleyberg, CT 94514'},
#  {'nombre': 'Kathleen Hebert',
#   'apellido': 'Duffy',
#   'email': 'christopher58@example.org',
#   'direccion': '0078 Pamela Highway Suite 916\nToddfurt, MN 76689'},
#  {'nombre': 'Tina Cruz',
#   'apellido': 'Young',
#   'email': 'nicole92@example.net',
#   'direccion': '85553 Samantha Parkways Suite 838\nMichellebury, VT 85127'},
#  {'nombre': 'William Jones',
#   'apellido': 'Reynolds',
#   'email': 'bboyd@example.com',
#   'direccion': '363 Seth Divide Apt. 317\nLake Mario, NJ 96881'},
#  {'nombre': 'Carlos Acosta',
#   'apellido': 'Walker',
#   'email': 'welchcaitlyn@example.org',
#   'direccion': '285 Nathan Street\nNew Charlesmouth, TN 18290'},
#  {'nombre': 'Miss Melissa Butler',
#   'apellido': 'Graham',
#   'email': 'xjones@example.org',
#   'direccion': '304 Joseph Stravenue Suite 363\nRachelstad, CT 67306'},
#  {'nombre': 'Brian Miller',
#   'apellido': 'Butler',
#   'email': 'christina07@example.org',
#   'direccion': 'PSC 2072, Box 7351\nAPO AP 25242'},
#  {'nombre': 'Michael Diaz',
#   'apellido': 'Reynolds',
#   'email': 'tyronebarber@example.com',
#   'direccion': '70011 Mccormick Plains\nEast Ianhaven, AL 54239'},
#  {'nombre': 'Sean Clay',
#   'apellido': 'Velasquez',
#   'email': 'yharvey@example.org',
#   'direccion': '109 Nathan Neck\nKimberlyton, OK 35557'},
#  {'nombre': 'Anthony Osborn',
#   'apellido': 'Pollard',
#   'email': 'crystaljones@example.net',
#   'direccion': '05947 Stone Courts Apt. 106\nEast Brittanyborough, HI 39255'},
#  {'nombre': 'Joseph House',
#   'apellido': 'Kennedy',
#   'email': 'fieldsdaniel@example.org',
#   'direccion': 'Unit 3124 Box 6498\nDPO AP 93456'},
#  {'nombre': 'John Franklin',
#   'apellido': 'Peters',
#   'email': 'mitchelldaniel@example.com',
#   'direccion': 'PSC 3691, Box 9328\nAPO AA 04692'},
#  {'nombre': 'Jessica Garcia',
#   'apellido': 'James',
#   'email': 'martinbrian@example.org',
#   'direccion': '88255 Rose Prairie\nWest Elizabeth, WV 46082'},
#  {'nombre': 'Joshua Gallegos',
#   'apellido': 'Wagner',
#   'email': 'kimberlymurphy@example.org',
#   'direccion': '764 Lopez Gardens\nLopezmouth, HI 67195'},
#  {'nombre': 'Nicole Rogers',
#   'apellido': 'Melton',
#   'email': 'kgarcia@example.com',
#   'direccion': '106 Stephanie Divide\nDavisside, DE 80806'},
#  {'nombre': 'Helen Gross',
#   'apellido': 'Mendez',
#   'email': 'deborahadams@example.org',
#   'direccion': '66796 Henderson Expressway Apt. 372\nPrattchester, WV 45839'},
#  {'nombre': 'Tara Lee',
#   'apellido': 'Miller',
#   'email': 'tdavid@example.com',
#   'direccion': '80136 Arroyo Spurs Apt. 612\nAndrewsberg, TN 21749'},
#  {'nombre': 'Robert Martinez',
#   'apellido': 'Castro',
#   'email': 'evansdarlene@example.net',
#   'direccion': '4062 Lawson Haven Apt. 833\nShawnfurt, LA 01407'},
#  ...]

# %%
import pandas as pd

# %%
data = pd.DataFrame(lista)

# %%
data
# Out:
#                     nombre  apellido                         email  \
# 0     George Hernandez PhD    Garcia          rnichols@example.com
# 1                Anna Beck     Clark       gomezsteven@example.com
# 2         Michael Williams     Baker  reynoldsbrittney@example.org
# 3      Mr. Stephen Simpson     Perez         paullopez@example.net
# 4               Ryan Allen     Mason         cfranklin@example.org
# ...                    ...       ...                           ...
# 9995     Crystal Rodriguez  Trujillo           uhoward@example.org
# 9996          Kelly Holmes     Rivas  feliciaalexander@example.com
# 9997           Angela Reid  Mitchell         osullivan@example.com
# 9998        Theresa Mendez    Gibson     amandameadows@example.net
# 9999           Megan Mccoy     Moore      gilestimothy@example.org
#
#                                               direccion
# 0                901 Reyes Ville\nWardchester, MH 18727
# 1     8312 Cindy Mountains Apt. 646\nNorth Summerlan...
# 2     288 Mcdonald Crossing\nSouth Georgemouth, DE 5...
# 3            631 Timothy Loop\nAntonioborough, MI 88544
# 4      31938 Amber Lock Apt. 984\nLake Sierra, VA 51249
# ...                                                 ...
# 9995   64487 Gonzalez Inlet\nEast Sherrimouth, AK 40993
# 9996    216 Simmons Haven Apt. 857\nLloydbury, NY 70179
# 9997             193 Erica Parks\nWheelerstad, NE 32837
# 9998          332 Blair Plains\nCarpenterstad, MT 98093
# 9999  5485 Jennifer Drive Suite 646\nHuffhaven, DC 2...
#
# [10000 rows x 4 columns]

# %%
import random as rd

# %%
def obtener_edad(d):
    edad=str(rd.randint(30,40))
    edad=edad+" años"
    return edad

# %%
provincias=['Loja', 'Pichincha', 'Guayas', 'Azuay', 'Manabí']

# %%
def obtener_provincia(p):
    provincia=rd.choice(provincias)
    return provincia

# %%
data['edad'] = data['nombre'].apply(obtener_edad)

# %%
data['provincia'] = data['nombre'].apply(obtener_provincia)

# %%
data
# Out:
#                     nombre  apellido                         email  \
# 0     George Hernandez PhD    Garcia          rnichols@example.com
# 1                Anna Beck     Clark       gomezsteven@example.com
# 2         Michael Williams     Baker  reynoldsbrittney@example.org
# 3      Mr. Stephen Simpson     Perez         paullopez@example.net
# 4               Ryan Allen     Mason         cfranklin@example.org
# ...                    ...       ...                           ...
# 9995     Crystal Rodriguez  Trujillo           uhoward@example.org
# 9996          Kelly Holmes     Rivas  feliciaalexander@example.com
# 9997           Angela Reid  Mitchell         osullivan@example.com
# 9998        Theresa Mendez    Gibson     amandameadows@example.net
# 9999           Megan Mccoy     Moore      gilestimothy@example.org
#
#                                               direccion     edad  provincia
# 0                901 Reyes Ville\nWardchester, MH 18727  38 años      Azuay
# 1     8312 Cindy Mountains Apt. 646\nNorth Summerlan...  33 años  Pichincha
# 2     288 Mcdonald Crossing\nSouth Georgemouth, DE 5...  32 años  Pichincha
# 3            631 Timothy Loop\nAntonioborough, MI 88544  32 años  Pichincha
# 4      31938 Amber Lock Apt. 984\nLake Sierra, VA 51249  30 años  Pichincha
# ...                                                 ...      ...        ...
# 9995   64487 Gonzalez Inlet\nEast Sherrimouth, AK 40993  39 años       Loja
# 9996    216 Simmons Haven Apt. 857\nLloydbury, NY 70179  38 años     Guayas
# 9997             193 Erica Parks\nWheelerstad, NE 32837  36 años  Pichincha
# 9998          332 Blair Plains\nCarpenterstad, MT 98093  33 años  Pichincha
# 9999  5485 Jennifer Drive Suite 646\nHuffhaven, DC 2...  36 años  Pichincha
#
# [10000 rows x 6 columns]

# %%
data.to_csv("cuaderno1.csv", index=False)
